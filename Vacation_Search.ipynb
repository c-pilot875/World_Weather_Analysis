# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("WeatherPy_Database.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0       Qaanaaq      GL  77.4840  -69.3632    -26.12        83
# 1        1  Ponta Do Sol      PT  32.6667  -17.1000     75.00        68
# 2        2        Barrow      US  71.2906 -156.7887     17.62        79
# 3        3    Blackwater      AU -23.5833  148.8833     61.30        81
# 4        4         Jizan      SA  17.3333   42.6667     82.92        63
#
#    Cloudiness  Wind Speed      Description
# 0           9        6.26        clear sky
# 1          17        6.62       few clouds
# 2         100        8.05  overcast clouds
# 3           0        7.40        clear sky
# 4           0        8.63        clear sky

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 65
# What is the maximum temperature you would like for your trip? 90

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]


# Display sample data
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 1         1    Ponta Do Sol      PT  32.6667  -17.1000     75.00        68
# 4         4           Jizan      SA  17.3333   42.6667     82.92        63
# 5         5            Adre      TD  13.4667   22.2000     88.90        19
# 6         6     East London      ZA -33.0153   27.9116     72.54        83
# 8         8           Akyab      MM  20.1500   92.9000     79.50        76
# 10       10           Kapaa      US  22.0752 -159.3190     73.72        86
# 15       15  Cabo San Lucas      MX  22.8909 -109.9124     74.52        74
# 16       16       Carnarvon      AU -24.8667  113.6333     69.89        75
# 20       20          Avarua      CK -21.2078 -159.7750     77.05        88
# 25       25          Xuddur      SO   4.1213   43.8894     84.63        32
#
#     Cloudiness  Wind Speed      Description
# 1           17        6.62       few clouds
# 4            0        8.63        clear sky
# 5           95        5.48  overcast clouds
# 6           20       12.66       few clouds
# 8            0       11.92        clear sky
# 10          20        8.05       light rain
# 15           0        1.99        clear sky
# 16           2       16.71        clear sky
# 20          75       13.80    broken clouds
# 25          76        9.42    broken clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# checking for null values. none identified by count.
preferred_cities_df.count()
# Out:
# City_ID        295
# City           295
# Country        292
# Lat            295
# Lng            295
# Max Temp       295
# Humidity       295
# Cloudiness     295
# Wind Speed     295
# Description    295
# dtype: int64

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna()
# Display sample data
clean_travel_cities.head()
# Out:
#    City_ID          City Country      Lat      Lng  Max Temp  Humidity  \
# 1        1  Ponta Do Sol      PT  32.6667 -17.1000     75.00        68
# 4        4         Jizan      SA  17.3333  42.6667     82.92        63
# 5        5          Adre      TD  13.4667  22.2000     88.90        19
# 6        6   East London      ZA -33.0153  27.9116     72.54        83
# 8        8         Akyab      MM  20.1500  92.9000     79.50        76
#
#    Cloudiness  Wind Speed      Description
# 1          17        6.62       few clouds
# 4           0        8.63        clear sky
# 5          95        5.48  overcast clouds
# 6          20       12.66       few clouds
# 8           0       11.92        clear sky

# %%
# Confirming dropped null values with count()
clean_travel_cities.count()
# Out:
# City_ID        292
# City           292
# Country        292
# Lat            292
# Lng            292
# Max Temp       292
# Humidity       292
# Cloudiness     292
# Wind Speed     292
# Description    292
# dtype: int64

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[['City','Country', 'Max Temp', 'Description', 'Lat', 'Lng']].copy()
hotel_df.head()
# Out:
#            City Country  Max Temp      Description      Lat      Lng
# 1  Ponta Do Sol      PT     75.00       few clouds  32.6667 -17.1000
# 4         Jizan      SA     82.92        clear sky  17.3333  42.6667
# 5          Adre      TD     88.90  overcast clouds  13.4667  22.2000
# 6   East London      ZA     72.54       few clouds -33.0153  27.9116
# 8         Akyab      MM     79.50        clear sky  20.1500  92.9000

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = ""


# Display sample data
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Description      Lat       Lng  \
# 1     Ponta Do Sol      PT     75.00       few clouds  32.6667  -17.1000
# 4            Jizan      SA     82.92        clear sky  17.3333   42.6667
# 5             Adre      TD     88.90  overcast clouds  13.4667   22.2000
# 6      East London      ZA     72.54       few clouds -33.0153   27.9116
# 8            Akyab      MM     79.50        clear sky  20.1500   92.9000
# 10           Kapaa      US     73.72       light rain  22.0752 -159.3190
# 15  Cabo San Lucas      MX     74.52        clear sky  22.8909 -109.9124
# 16       Carnarvon      AU     69.89        clear sky -24.8667  113.6333
# 20          Avarua      CK     77.05    broken clouds -21.2078 -159.7750
# 25          Xuddur      SO     84.63    broken clouds   4.1213   43.8894
#
#    Hotel Name
# 1
# 4
# 5
# 6
# 8
# 10
# 15
# 16
# 20
# 25

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Ponta Do Sol - nearest hotel: Estalagem Ponta do Sol
# Jizan - nearest hotel: No hotel found
# Adre - nearest hotel: No hotel found
# East London - nearest hotel: No hotel found
# Akyab - nearest hotel: Yuzana Aung Motel 1
# Kapaa - nearest hotel: Pono Kai Resort
# Cabo San Lucas - nearest hotel: Comfort Rooms
# Carnarvon - nearest hotel: No hotel found
# Avarua - nearest hotel: Paradise Inn
# Xuddur - nearest hotel: No hotel found
# Castro - nearest hotel: Hotel Central Palace
# Kampot - nearest hotel: Sambor Sambat Guesthouse
# Sikonge - nearest hotel: Kaluvya hotel and shopping center
# Villa Del Rosario - nearest hotel: Acapulco
# Yangambi - nearest hotel: No hotel found
# Atuona - nearest hotel: Pearl Resort
# Saint-Philippe - nearest hotel: Le Baril
# Vaini - nearest hotel: Keleti International Resort
# Riyadh - nearest hotel: White Palace Hotel
# Labuhan - nearest hotel: No hotel found
# Kieta - nearest hotel: No hotel found
# Cape Town - nearest hotel: Townhouse Hotel
# Takoradi - nearest hotel: Hillcrest
# Bambous Virieux - nearest hotel: No hotel found
# Villa Union - nearest hotel: No hotel found
# Matara - nearest hotel: Villa Palm Breeze
# Guerrero - nearest hotel: No hotel found
# Constitucion - nearest hotel: Hostal Alameda
# Arlit - nearest hotel: No hotel found
# Praya - nearest hotel: Casa Sodadi
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Bonfim - nearest hotel: No hotel found
# Chingola - nearest hotel: Protea Hotel
# Mar Del Plata - nearest hotel: Nuevo Ostende
# Tezu - nearest hotel: No hotel found
# Daru - nearest hotel: Kuki
# Ambilobe - nearest hotel: Hôtel National
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Port Augusta - nearest hotel: Hotel Commonwealth
# Piacabucu - nearest hotel: O Leão
# Pisco - nearest hotel: La Portada
# Souillac - nearest hotel: Hotel SkylineInn
# Chuy - nearest hotel: Alerces
# Camacha - nearest hotel: Praia Dourada
# Punta Alta - nearest hotel: Gran Hotel
# Khammam - nearest hotel: Sindhu
# Hermanus - nearest hotel: Aloe guest house
# Biak - nearest hotel: No hotel found
# Kiunga - nearest hotel: No hotel found
# Tandil - nearest hotel: Viñas del Rosario Hotel Boutique
# Monrovia - nearest hotel: Bella Casa Hotel
# Oranjestad - nearest hotel: Hotel California
# Kahului - nearest hotel: Maui Seaside Hotel
# Kavaratti - nearest hotel: No hotel found
# Salalah - nearest hotel: Muscat International Hotel
# Port-Gentil - nearest hotel: Tara-Mé
# Hualmay - nearest hotel: Hotel Mi Choacan
# Port Alfred - nearest hotel: No hotel found
# Saldanha - nearest hotel: Hoedjesbaai
# Butaritari - nearest hotel: No hotel found
# Garowe - nearest hotel: Red Sea
# Bibiani - nearest hotel: Addai's Hotel
# San Lorenzo - nearest hotel: Hotel del Sur
# Comodoro Rivadavia - nearest hotel: No hotel found
# Mgandu - nearest hotel: No hotel found
# Marsh Harbour - nearest hotel: Lofty Fig Villas
# Vallenar - nearest hotel: Hotel del Marqués
# Jibuti - nearest hotel: No hotel found
# Bonga - nearest hotel: No hotel found
# Arraial Do Cabo - nearest hotel: No hotel found
# Talcahuano - nearest hotel: Club Recreativo Armada de Chile
# Kalmunai - nearest hotel: Saji new food
# Anloga - nearest hotel: Hotel de White House
# Gat - nearest hotel: No hotel found
# Bredasdorp - nearest hotel: Victoria Hotel
# Marang - nearest hotel: Hotel Syahirah
# Sao Filipe - nearest hotel: Bela Vista
# Port Elizabeth - nearest hotel: Waterford Hotel
# Pundaguitan - nearest hotel: No hotel found
# Caldas Novas - nearest hotel: Hotel Roma
# Carutapera - nearest hotel: No hotel found
# Tirukkoyilur - nearest hotel: No hotel found
# Kununurra - nearest hotel: Kununurra Country Club Resort
# Madimba - nearest hotel: No hotel found
# Kruisfontein - nearest hotel: No hotel found
# Mahibadhoo - nearest hotel: Coral View Inn
# Hilo - nearest hotel: Dolphin Bay Hotel
# Eyl - nearest hotel: فندق ايل دابي
# Bahia Blanca - nearest hotel: Hotel Austral Bahía
# Angoram - nearest hotel: No hotel found
# Nandyal - nearest hotel: No hotel found
# Alofi - nearest hotel: No hotel found
# Katobu - nearest hotel: No hotel found
# Georgetown - nearest hotel: Page 63 hostel
# Gao - nearest hotel: No hotel found
# Dakar - nearest hotel: 翁记小吃
# Maldonado - nearest hotel: No hotel found
# Maine-Soroa - nearest hotel: Maïné-Soroa
# Isangel - nearest hotel: Tanna Lodge
# Boueni - nearest hotel: La Case Robinson
# Nhulunbuy - nearest hotel: No hotel found
# Cidreira - nearest hotel: Hotel Castelo
# Saint-Pierre - nearest hotel: Tropic Hotel
# Sechura - nearest hotel: Hospedaje Claritza
# Fonte Boa - nearest hotel: No hotel found
# Cururupu - nearest hotel: No hotel found
# Merauke - nearest hotel: No hotel found
# Bengkulu - nearest hotel: Dena Hotel
# Karratha - nearest hotel: Karratha International Hotel
# Eldorado - nearest hotel: Hotel Laçador
# Itarema - nearest hotel: Pousada Oásis
# Pasighat - nearest hotel: Aane Hotel
# Kencong - nearest hotel: No hotel found
# Aquiraz - nearest hotel: Pousada tia Fabíola
# Tessalit - nearest hotel: No hotel found
# Mahebourg - nearest hotel: Grand Bel Air
# Rio Grande - nearest hotel: Hotel Vila Moura Executivo
# Floresta - nearest hotel: Floresta Hotel
# Acajutla - nearest hotel: Hotel Lara
# Lagunas - nearest hotel: Hospedaje Eco
# Imbituba - nearest hotel: Silvestre Praia Hotel
# Jungapeo - nearest hotel: Xungapety
# Los Llanos De Aridane - nearest hotel: Valle Aridane
# Port Hedland - nearest hotel: The Esplanade Hotel
# Doha - nearest hotel: Al MIrqab
# Da Nang - nearest hotel: Thanh Thanh Hotel
# Palembang - nearest hotel: OYO 183 The Pipe House
# Neiafu - nearest hotel: Port Wine Guest House
# Hithadhoo - nearest hotel: Pebbles Inn
# Xai-Xai - nearest hotel: No hotel found
# Caravelas - nearest hotel: Pousada dos Navegantes
# Wanning - nearest hotel: No hotel found
# Fontem - nearest hotel: No hotel found
# Dingle - nearest hotel: No hotel found
# Bandarbeyla - nearest hotel: No hotel found
# Hirara - nearest hotel: 古謝そば屋
# Port Blair - nearest hotel: Andaman Ocean Breeze
# Mount Isa - nearest hotel: Ibis Styles
# Vung Tau - nearest hotel: No hotel found
# Madras - nearest hotel: Blue Star International
# Ilo - nearest hotel: Hostal Central
# Bathsheba - nearest hotel: Atlantis Hotel
# Nelson Bay - nearest hotel: No hotel found
# Inirida - nearest hotel: Residencias El Turista del Guainia
# Haapiti - nearest hotel: No hotel found
# Faanui - nearest hotel: Oa Oa Lodge
# Grand Gaube - nearest hotel: Coco Villa
# Darnah - nearest hotel: فندق الفردوس
# Inhambane - nearest hotel: Hotel de Inhambane
# Itaituba - nearest hotel: TG Hotel
# Jijiga - nearest hotel: Africa Hotel
# Yulara - nearest hotel: Outback Pioneer Hotel & Lodge
# Keti Bandar - nearest hotel: No hotel found
# Kisesa - nearest hotel: No hotel found
# Sambava - nearest hotel: Royal Sava Hôtel
# Kabompo - nearest hotel: No hotel found
# Kudahuvadhoo - nearest hotel: No hotel found
# Diplo - nearest hotel: No hotel found
# Andros Town - nearest hotel: No hotel found
# Robertsport - nearest hotel: Nana's Lodge
# Mitsamiouli - nearest hotel: Hotel le Paradis
# Sinnamary - nearest hotel: Hôtel du fleuve
# Mbigou - nearest hotel: No hotel found
# Loiza - nearest hotel: No hotel found
# Sao Miguel Do Araguaia - nearest hotel: Hotel São Miguel
# Karachi - nearest hotel: Quetta Agha Hotel
# Vilhena - nearest hotel: No hotel found
# Nakhon Phanom - nearest hotel: No hotel found
# Mangrol - nearest hotel: No hotel found
# Tartus - nearest hotel: شاهين القديم
# Tomatlan - nearest hotel: Hotel Hacienda Vieja Tomatlan
# Boa Vista - nearest hotel: Aipana Plaza Hotel
# San Luis - nearest hotel: Hotel Dos Venados
# Buta - nearest hotel: Hôtel Rubi
# Acapulco - nearest hotel: Hotel del Valle
# Pangai - nearest hotel: Billy's Place
# Rocha - nearest hotel: Hotel Municipal
# Kupang - nearest hotel: BIB & LANG GUEST HOUSE
# Luanda - nearest hotel: Hotel Forum
# Araouane - nearest hotel: No hotel found
# Coquimbo - nearest hotel: Hotel Iberia
# Manggar - nearest hotel: No hotel found
# Bubaque - nearest hotel: Chez Julio
# Fare - nearest hotel: hôtel Maitai Lapita Village
# Yeppoon - nearest hotel: Blossom's on Seaspray
# Harper - nearest hotel: No hotel found
# Isabela - nearest hotel: No hotel found
# Porto Santo - nearest hotel: Praia Dourada
# Cayenne - nearest hotel: Central Hôtel
# Tamandare - nearest hotel: Pousada Baia dos Corais
# Mozarlandia - nearest hotel: No hotel found
# Pathein - nearest hotel: Taan Taan Ta
# Rajgarh - nearest hotel: No hotel found
# Tucurui - nearest hotel: No hotel found
# Basco - nearest hotel: Tawsen Hotel
# Sharjah - nearest hotel: shakeel bhai room
# Wattegama - nearest hotel: No hotel found
# Namatanai - nearest hotel: Namatanai Hotel
# Whyalla - nearest hotel: Whyalla Playford Apartments
# Kidal - nearest hotel: No hotel found
# Kavieng - nearest hotel: Kavieng Hotel
# Moreira Sales - nearest hotel: No hotel found
# Trairi - nearest hotel: No hotel found
# Martin - nearest hotel: No hotel found
# Noumea - nearest hotel: Hotel Gondwana
# Dwarka - nearest hotel: The Dwarika Hotel
# Alenquer - nearest hotel: No hotel found
# Bima - nearest hotel: No hotel found
# Namibe - nearest hotel: Hotel Chik Chik Namibe
# Itaporanga - nearest hotel: Hotel Rainha do Vale
# Sibolga - nearest hotel: Hotel Prima Indah
# Camacupa - nearest hotel: No hotel found
# Muisne - nearest hotel: Hostal Té de Menta
# Bilma - nearest hotel: No hotel found
# Mabaruma - nearest hotel: Monty Brooms Hotel
# Maumere - nearest hotel: Bogor
# Meulaboh - nearest hotel: Hotel Meuligou
# Pochutla - nearest hotel: Hotel El Patio
# Taitung - nearest hotel: 瑞軒民宿
# Chipata - nearest hotel: Kamocho Gueshouse
# Alyangula - nearest hotel: No hotel found
# Boende - nearest hotel: No hotel found
# Broken Hill - nearest hotel: Ibis Styles
# Sabang - nearest hotel: Sabang Hill
# Awjilah - nearest hotel: No hotel found
# Touros - nearest hotel: Pousada Atlântico
# Barberena - nearest hotel: No hotel found
# Norton - nearest hotel: Village Pakare Paye
# Baculin - nearest hotel: No hotel found
# Bosaso - nearest hotel: Bosaso hotel
# Thinadhoo - nearest hotel: No hotel found
# Plettenberg Bay - nearest hotel: Milkwood Manor
# Gigmoto - nearest hotel: No hotel found
# The Valley - nearest hotel: CeBlue
# Tabou - nearest hotel: hôtel le rochet
# Lima - nearest hotel: Hotel Peach Garden
# Palmas Bellas - nearest hotel: ISHQ AirBnb
# Buraydah - nearest hotel: دنا للوحدات السكنية
# Tupaciguara - nearest hotel: Macauba
# Baleshwar - nearest hotel: Dropadi
# Hambantota - nearest hotel: Oasis Aurweda Resort Hambathota
# Hobyo - nearest hotel: No hotel found
# Kutum - nearest hotel: No hotel found
# Linhares - nearest hotel: Days Inn Linhares
# Nakhon Nayok - nearest hotel: No hotel found
# Maues - nearest hotel: No hotel found
# Pangkalanbuun - nearest hotel: Hotel Tiara
# Sao Joao Da Barra - nearest hotel: Pousada Mediterrâneo
# Honiara - nearest hotel: King Solomon Hotel
# Mahanoro - nearest hotel: Vanilla Bungalow
# Adeje - nearest hotel: Royal Garden Villas
# Chirongui - nearest hotel: No hotel found
# La Orilla - nearest hotel: Victoria
# Sarangani - nearest hotel: No hotel found
# Tabatinga - nearest hotel: Hotel Solimões
# Guaraniacu - nearest hotel: No hotel found
# Tocopilla - nearest hotel: hotel Isidora
# Sola - nearest hotel: No hotel found
# Buala - nearest hotel: No hotel found
# Miramar - nearest hotel: El Palacio Sports Hotel
# Iranshahr - nearest hotel: هتل قصِر
# Male - nearest hotel: Champa Central Hotel
# Bani - nearest hotel: HOTEL GLAMOURS
# Ixtapa - nearest hotel: No hotel found
# Asosa - nearest hotel: Africa Hotel
# Ingraj Bazar - nearest hotel: Raj Hotel
# Alexandria - nearest hotel: Smoha Zahran Haus (7th floor)
# Kloulklubed - nearest hotel: The Adventures Inn
# Bom Jesus - nearest hotel: Hotel Brasão
# Mahina - nearest hotel: Motu Martin
# Sao Jose Da Coroa Grande - nearest hotel: Hotel do Sol
# Esna - nearest hotel: No hotel found
# Benguela - nearest hotel: Hotel Moibela
# La Union - nearest hotel: No hotel found
# Tres Palos - nearest hotel: No hotel found
# Kerema - nearest hotel: Kerema Hotel
# Bauchi - nearest hotel: No hotel found
# Caruray - nearest hotel: No hotel found
# Piranhas - nearest hotel: No hotel found
# Puerto Leguizamo - nearest hotel: Hotel Girasoles
# Abnub - nearest hotel: No hotel found
# Ishigaki - nearest hotel: アートホテル石垣島
# Aitape - nearest hotel: No hotel found
# Mackay - nearest hotel: Mackay Oceanside Central Apartment Hotel
# Ternate - nearest hotel: Boulivard ternate
# Tutoia - nearest hotel: Pousada San Vicente
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Kibala - nearest hotel: No hotel found
# Los Algarrobos - nearest hotel: No hotel found
# Tebingtinggi - nearest hotel: No hotel found
# Ca Mau - nearest hotel: Khách sạn Song Ngọc
# Kasongo-Lunda - nearest hotel: No hotel found
#                City Country  Max Temp       Description      Lat       Lng  \
# 1      Ponta Do Sol      PT     75.00        few clouds  32.6667  -17.1000
# 4             Jizan      SA     82.92         clear sky  17.3333   42.6667
# 5              Adre      TD     88.90   overcast clouds  13.4667   22.2000
# 6       East London      ZA     72.54        few clouds -33.0153   27.9116
# 8             Akyab      MM     79.50         clear sky  20.1500   92.9000
# ..              ...     ...       ...               ...      ...       ...
# 665          Kibala      TD     89.69   overcast clouds   9.1104   18.3463
# 668  Los Algarrobos      PA     81.01  scattered clouds   8.5000  -82.4333
# 669    Tebingtinggi      ID     74.53   overcast clouds   3.3285   99.1625
# 670          Ca Mau      VN     76.59   overcast clouds   9.1769  105.1500
# 672   Kasongo-Lunda      CD     81.14   overcast clouds  -6.4667   16.8167
#
#                  Hotel Name
# 1    Estalagem Ponta do Sol
# 4            No hotel found
# 5            No hotel found
# 6            No hotel found
# 8       Yuzana Aung Motel 1
# ..                      ...
# 665          No hotel found
# 668          No hotel found
# 669          No hotel found
# 670     Khách sạn Song Ngọc
# 672          No hotel found
#
# [292 rows x 7 columns]

# %%
hotel_df.count()
# Out:
# City           292
# Country        292
# Max Temp       292
# Description    292
# Lat            292
# Lng            292
# Hotel Name     292
# dtype: int64

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df["Hotel Name"] != "No hotel found"]

# Display sample data
clean_hotel_df.head()
# Out:
#               City Country  Max Temp    Description      Lat       Lng  \
# 1     Ponta Do Sol      PT     75.00     few clouds  32.6667  -17.1000
# 8            Akyab      MM     79.50      clear sky  20.1500   92.9000
# 10           Kapaa      US     73.72     light rain  22.0752 -159.3190
# 15  Cabo San Lucas      MX     74.52      clear sky  22.8909 -109.9124
# 20          Avarua      CK     77.05  broken clouds -21.2078 -159.7750
#
#                 Hotel Name
# 1   Estalagem Ponta do Sol
# 8      Yuzana Aung Motel 1
# 10         Pono Kai Resort
# 15           Comfort Rooms
# 20            Paradise Inn

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_data_file = "Vacation_Databse.csv"

# Export the city_data DataFrame into a CSV file
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country)
