# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    

    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 732

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, and weather description
        city_weather = requests.get(city_url).json()    
            
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,
                          "Country": city_country})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | blackwater
# Processing Record 5 of Set 1 | jizan
# Processing Record 6 of Set 1 | adre
# Processing Record 7 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | akyab
# Processing Record 11 of Set 1 | kaeo
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | simao
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | saint anthony
# Processing Record 16 of Set 1 | shimoda
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | talawdi
# City not found. Skipping...
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | belton
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | kaitangata
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | xuddur
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | kampot
# Processing Record 32 of Set 1 | erenhot
# Processing Record 33 of Set 1 | sikonge
# Processing Record 34 of Set 1 | villa del rosario
# Processing Record 35 of Set 1 | yangambi
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 1 | riyadh
# Processing Record 43 of Set 1 | labuhan
# Processing Record 44 of Set 1 | kieta
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | severo-kurilsk
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | porto walter
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | geraldton
# Processing Record 1 of Set 2 | takoradi
# Processing Record 2 of Set 2 | tambacounda
# Processing Record 3 of Set 2 | pevek
# Processing Record 4 of Set 2 | paamiut
# Processing Record 5 of Set 2 | bambous virieux
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | villa union
# Processing Record 8 of Set 2 | matara
# Processing Record 9 of Set 2 | guerrero
# Processing Record 10 of Set 2 | constitucion
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | belluno
# Processing Record 13 of Set 2 | shirokiy
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | cherskiy
# Processing Record 16 of Set 2 | arlit
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | flinders
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | praya
# Processing Record 21 of Set 2 | rikitea
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | burica
# City not found. Skipping...
# Processing Record 25 of Set 2 | obama
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | bonfim
# Processing Record 28 of Set 2 | sanjwal
# Processing Record 29 of Set 2 | aykhal
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | yaan
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | chingola
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | ures
# Processing Record 36 of Set 2 | tura
# Processing Record 37 of Set 2 | port hardy
# Processing Record 38 of Set 2 | tezu
# Processing Record 39 of Set 2 | daru
# Processing Record 40 of Set 2 | dali
# Processing Record 41 of Set 2 | lermontov
# Processing Record 42 of Set 2 | krasnoselkup
# Processing Record 43 of Set 2 | ambilobe
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | provideniya
# Processing Record 46 of Set 2 | port augusta
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | piacabucu
# Processing Record 49 of Set 2 | port arthur
# Processing Record 50 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 3 | pisco
# Processing Record 2 of Set 3 | knoxville
# Processing Record 3 of Set 3 | souillac
# Processing Record 4 of Set 3 | north bend
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | mehamn
# Processing Record 7 of Set 3 | sindor
# Processing Record 8 of Set 3 | fairbanks
# Processing Record 9 of Set 3 | katsuura
# Processing Record 10 of Set 3 | saint-augustin
# Processing Record 11 of Set 3 | te anau
# Processing Record 12 of Set 3 | camacha
# Processing Record 13 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 14 of Set 3 | okhotsk
# Processing Record 15 of Set 3 | ksenyevka
# City not found. Skipping...
# Processing Record 16 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 3 | punta alta
# Processing Record 19 of Set 3 | khammam
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | biak
# Processing Record 22 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 3 | makarov
# Processing Record 24 of Set 3 | raga
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | ancud
# Processing Record 27 of Set 3 | aldan
# Processing Record 28 of Set 3 | andenes
# Processing Record 29 of Set 3 | las vegas
# Processing Record 30 of Set 3 | upernavik
# Processing Record 31 of Set 3 | kiunga
# Processing Record 32 of Set 3 | tandil
# Processing Record 33 of Set 3 | victoria
# Processing Record 34 of Set 3 | monrovia
# Processing Record 35 of Set 3 | oranjestad
# Processing Record 36 of Set 3 | kahului
# Processing Record 37 of Set 3 | kavaratti
# Processing Record 38 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 3 | kangaatsiaq
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | salalah
# Processing Record 42 of Set 3 | tiksi
# Processing Record 43 of Set 3 | anapskaya
# Processing Record 44 of Set 3 | kerman
# Processing Record 45 of Set 3 | lagoa
# Processing Record 46 of Set 3 | turukhansk
# Processing Record 47 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 48 of Set 3 | port-gentil
# Processing Record 49 of Set 3 | yalutorovsk
# Processing Record 50 of Set 3 | hualmay
# Processing Record 1 of Set 4 | ayan
# Processing Record 2 of Set 4 | saint george
# Processing Record 3 of Set 4 | port alfred
# Processing Record 4 of Set 4 | saldanha
# Processing Record 5 of Set 4 | butaritari
# Processing Record 6 of Set 4 | garowe
# Processing Record 7 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 4 | aalburg
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | bibiani
# Processing Record 11 of Set 4 | prince george
# Processing Record 12 of Set 4 | lata
# Processing Record 13 of Set 4 | waipawa
# Processing Record 14 of Set 4 | san lorenzo
# Processing Record 15 of Set 4 | tuatapere
# Processing Record 16 of Set 4 | nome
# Processing Record 17 of Set 4 | comodoro rivadavia
# Processing Record 18 of Set 4 | korla
# Processing Record 19 of Set 4 | ust-kuyga
# Processing Record 20 of Set 4 | dunedin
# Processing Record 21 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 4 | mgandu
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | srednekolymsk
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | marsh harbour
# Processing Record 27 of Set 4 | vallenar
# Processing Record 28 of Set 4 | vitim
# Processing Record 29 of Set 4 | jibuti
# Processing Record 30 of Set 4 | muko
# Processing Record 31 of Set 4 | ahipara
# Processing Record 32 of Set 4 | vysokogornyy
# Processing Record 33 of Set 4 | bicaz
# Processing Record 34 of Set 4 | bonga
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | clyde river
# Processing Record 37 of Set 4 | talcahuano
# Processing Record 38 of Set 4 | kalmunai
# Processing Record 39 of Set 4 | sept-iles
# Processing Record 40 of Set 4 | oda
# Processing Record 41 of Set 4 | dzhebariki-khaya
# Processing Record 42 of Set 4 | khatanga
# Processing Record 43 of Set 4 | anloga
# Processing Record 44 of Set 4 | prince rupert
# Processing Record 45 of Set 4 | gat
# Processing Record 46 of Set 4 | valea ierii
# Processing Record 47 of Set 4 | bredasdorp
# Processing Record 48 of Set 4 | yarmouth
# Processing Record 49 of Set 4 | lasa
# Processing Record 50 of Set 4 | marathon
# Processing Record 1 of Set 5 | oussouye
# Processing Record 2 of Set 5 | marang
# Processing Record 3 of Set 5 | narsaq
# Processing Record 4 of Set 5 | sao filipe
# Processing Record 5 of Set 5 | port elizabeth
# Processing Record 6 of Set 5 | pundaguitan
# Processing Record 7 of Set 5 | caldas novas
# Processing Record 8 of Set 5 | bethel
# Processing Record 9 of Set 5 | seoul
# Processing Record 10 of Set 5 | moncao
# Processing Record 11 of Set 5 | beringovskiy
# Processing Record 12 of Set 5 | carutapera
# Processing Record 13 of Set 5 | tirukkoyilur
# Processing Record 14 of Set 5 | port lincoln
# Processing Record 15 of Set 5 | chernyshevskiy
# Processing Record 16 of Set 5 | kununurra
# Processing Record 17 of Set 5 | saskylakh
# Processing Record 18 of Set 5 | madimba
# Processing Record 19 of Set 5 | kruisfontein
# Processing Record 20 of Set 5 | hazorasp
# Processing Record 21 of Set 5 | mahibadhoo
# Processing Record 22 of Set 5 | hilo
# Processing Record 23 of Set 5 | eyl
# Processing Record 24 of Set 5 | bahia blanca
# Processing Record 25 of Set 5 | marfino
# Processing Record 26 of Set 5 | angoram
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | nandyal
# Processing Record 29 of Set 5 | uzventis
# Processing Record 30 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 5 | kalmar
# Processing Record 32 of Set 5 | fortuna
# Processing Record 33 of Set 5 | alofi
# Processing Record 34 of Set 5 | chenghai
# Processing Record 35 of Set 5 | bilibino
# Processing Record 36 of Set 5 | katobu
# Processing Record 37 of Set 5 | georgetown
# Processing Record 38 of Set 5 | gao
# Processing Record 39 of Set 5 | dakar
# Processing Record 40 of Set 5 | kiama
# Processing Record 41 of Set 5 | maldonado
# Processing Record 42 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 5 | maine-soroa
# Processing Record 44 of Set 5 | isangel
# Processing Record 45 of Set 5 | carlsbad
# Processing Record 46 of Set 5 | boueni
# Processing Record 47 of Set 5 | pahrump
# Processing Record 48 of Set 5 | nhulunbuy
# Processing Record 49 of Set 5 | cidreira
# Processing Record 50 of Set 5 | jabinyanah
# Processing Record 1 of Set 6 | saint-pierre
# Processing Record 2 of Set 6 | sechura
# Processing Record 3 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 6 | fonte boa
# Processing Record 5 of Set 6 | san quintin
# Processing Record 6 of Set 6 | salinas
# Processing Record 7 of Set 6 | vernon
# Processing Record 8 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 6 | cururupu
# Processing Record 10 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 11 of Set 6 | rio gallegos
# Processing Record 12 of Set 6 | merauke
# Processing Record 13 of Set 6 | hede
# Processing Record 14 of Set 6 | along
# Processing Record 15 of Set 6 | byron bay
# Processing Record 16 of Set 6 | bengkulu
# Processing Record 17 of Set 6 | karratha
# Processing Record 18 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 6 | gunnedah
# Processing Record 20 of Set 6 | eldorado
# Processing Record 21 of Set 6 | san patricio
# Processing Record 22 of Set 6 | itarema
# Processing Record 23 of Set 6 | dukat
# Processing Record 24 of Set 6 | pasighat
# Processing Record 25 of Set 6 | port macquarie
# Processing Record 26 of Set 6 | savonlinna
# Processing Record 27 of Set 6 | melenki
# Processing Record 28 of Set 6 | kencong
# Processing Record 29 of Set 6 | aquiraz
# Processing Record 30 of Set 6 | menzelinsk
# Processing Record 31 of Set 6 | ribas do rio pardo
# Processing Record 32 of Set 6 | polunochnoye
# Processing Record 33 of Set 6 | tasiilaq
# Processing Record 34 of Set 6 | lock haven
# Processing Record 35 of Set 6 | pacific grove
# Processing Record 36 of Set 6 | tessalit
# Processing Record 37 of Set 6 | mnogovershinnyy
# Processing Record 38 of Set 6 | pampa
# Processing Record 39 of Set 6 | mahebourg
# Processing Record 40 of Set 6 | jiuquan
# Processing Record 41 of Set 6 | rio grande
# Processing Record 42 of Set 6 | floresta
# Processing Record 43 of Set 6 | acajutla
# Processing Record 44 of Set 6 | lagunas
# Processing Record 45 of Set 6 | imbituba
# Processing Record 46 of Set 6 | lompoc
# Processing Record 47 of Set 6 | nador
# Processing Record 48 of Set 6 | leshukonskoye
# Processing Record 49 of Set 6 | douentza
# Processing Record 50 of Set 6 | jungapeo
# Processing Record 1 of Set 7 | los llanos de aridane
# Processing Record 2 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 7 | port hedland
# Processing Record 4 of Set 7 | egvekinot
# Processing Record 5 of Set 7 | tazovskiy
# Processing Record 6 of Set 7 | doha
# Processing Record 7 of Set 7 | hasaki
# Processing Record 8 of Set 7 | verkhnyaya inta
# Processing Record 9 of Set 7 | da nang
# Processing Record 10 of Set 7 | boca do acre
# Processing Record 11 of Set 7 | portland
# Processing Record 12 of Set 7 | hibbing
# Processing Record 13 of Set 7 | palembang
# Processing Record 14 of Set 7 | neiafu
# Processing Record 15 of Set 7 | ravenna
# Processing Record 16 of Set 7 | hithadhoo
# Processing Record 17 of Set 7 | castrillon
# Processing Record 18 of Set 7 | glendive
# Processing Record 19 of Set 7 | xai-xai
# Processing Record 20 of Set 7 | creemore
# Processing Record 21 of Set 7 | weinan
# Processing Record 22 of Set 7 | caravelas
# Processing Record 23 of Set 7 | hurricane
# Processing Record 24 of Set 7 | fianga
# City not found. Skipping...
# Processing Record 25 of Set 7 | wanning
# Processing Record 26 of Set 7 | reconquista
# Processing Record 27 of Set 7 | kingaroy
# Processing Record 28 of Set 7 | fontem
# Processing Record 29 of Set 7 | ostrovnoy
# Processing Record 30 of Set 7 | liverpool
# Processing Record 31 of Set 7 | dingle
# Processing Record 32 of Set 7 | bandarbeyla
# Processing Record 33 of Set 7 | shadrinsk
# Processing Record 34 of Set 7 | hirara
# Processing Record 35 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 36 of Set 7 | port blair
# Processing Record 37 of Set 7 | mount isa
# Processing Record 38 of Set 7 | leningradskiy
# Processing Record 39 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 7 | burns lake
# Processing Record 41 of Set 7 | vung tau
# Processing Record 42 of Set 7 | aasiaat
# Processing Record 43 of Set 7 | muros
# Processing Record 44 of Set 7 | madras
# Processing Record 45 of Set 7 | ilo
# Processing Record 46 of Set 7 | anchorage
# Processing Record 47 of Set 7 | shaoxing
# Processing Record 48 of Set 7 | bathsheba
# Processing Record 49 of Set 7 | ganserndorf
# Processing Record 50 of Set 7 | alice springs
# Processing Record 1 of Set 8 | havre-saint-pierre
# Processing Record 2 of Set 8 | tarauaca
# Processing Record 3 of Set 8 | nelson bay
# Processing Record 4 of Set 8 | inirida
# Processing Record 5 of Set 8 | haapiti
# Processing Record 6 of Set 8 | christchurch
# Processing Record 7 of Set 8 | faanui
# Processing Record 8 of Set 8 | morales
# Processing Record 9 of Set 8 | grand gaube
# Processing Record 10 of Set 8 | laguna
# Processing Record 11 of Set 8 | darnah
# Processing Record 12 of Set 8 | baykit
# Processing Record 13 of Set 8 | pavino
# Processing Record 14 of Set 8 | chokurdakh
# Processing Record 15 of Set 8 | igarka
# Processing Record 16 of Set 8 | dasuya
# Processing Record 17 of Set 8 | inhambane
# Processing Record 18 of Set 8 | saint-claude
# Processing Record 19 of Set 8 | itaituba
# Processing Record 20 of Set 8 | churapcha
# Processing Record 21 of Set 8 | jijiga
# Processing Record 22 of Set 8 | strezhevoy
# Processing Record 23 of Set 8 | henties bay
# Processing Record 24 of Set 8 | yulara
# Processing Record 25 of Set 8 | jinchang
# Processing Record 26 of Set 8 | keti bandar
# Processing Record 27 of Set 8 | aklavik
# Processing Record 28 of Set 8 | kisesa
# Processing Record 29 of Set 8 | ullapool
# Processing Record 30 of Set 8 | mount gambier
# Processing Record 31 of Set 8 | vestmannaeyjar
# Processing Record 32 of Set 8 | dobson
# Processing Record 33 of Set 8 | hofn
# Processing Record 34 of Set 8 | sambava
# Processing Record 35 of Set 8 | zheleznodorozhnyy
# Processing Record 36 of Set 8 | kabompo
# Processing Record 37 of Set 8 | zhangye
# Processing Record 38 of Set 8 | kudahuvadhoo
# Processing Record 39 of Set 8 | diplo
# Processing Record 40 of Set 8 | andros town
# Processing Record 41 of Set 8 | robertsport
# Processing Record 42 of Set 8 | nuuk
# Processing Record 43 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 8 | pauini
# Processing Record 45 of Set 8 | tumen
# Processing Record 46 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 8 | mitsamiouli
# Processing Record 48 of Set 8 | sinnamary
# Processing Record 49 of Set 8 | mbigou
# Processing Record 50 of Set 8 | bridlington
# Processing Record 1 of Set 9 | loiza
# Processing Record 2 of Set 9 | sao miguel do araguaia
# Processing Record 3 of Set 9 | zhezkazgan
# Processing Record 4 of Set 9 | ust-tsilma
# Processing Record 5 of Set 9 | komsomolskiy
# Processing Record 6 of Set 9 | shieli
# Processing Record 7 of Set 9 | huichapan
# Processing Record 8 of Set 9 | colorado
# Processing Record 9 of Set 9 | zarichne
# Processing Record 10 of Set 9 | serdobsk
# Processing Record 11 of Set 9 | grootfontein
# Processing Record 12 of Set 9 | kintampo
# Processing Record 13 of Set 9 | mount pleasant
# Processing Record 14 of Set 9 | asau
# Processing Record 15 of Set 9 | nanortalik
# Processing Record 16 of Set 9 | nemuro
# Processing Record 17 of Set 9 | husavik
# Processing Record 18 of Set 9 | dandong
# Processing Record 19 of Set 9 | duz
# City not found. Skipping...
# Processing Record 20 of Set 9 | karachi
# Processing Record 21 of Set 9 | codrington
# Processing Record 22 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 23 of Set 9 | baglan
# Processing Record 24 of Set 9 | vilhena
# Processing Record 25 of Set 9 | bam
# Processing Record 26 of Set 9 | birnin kebbi
# Processing Record 27 of Set 9 | berlevag
# Processing Record 28 of Set 9 | ozinki
# Processing Record 29 of Set 9 | nakhon phanom
# Processing Record 30 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 31 of Set 9 | mangrol
# Processing Record 32 of Set 9 | torbay
# Processing Record 33 of Set 9 | nago
# Processing Record 34 of Set 9 | corsicana
# Processing Record 35 of Set 9 | tartus
# Processing Record 36 of Set 9 | spassk-ryazanskiy
# Processing Record 37 of Set 9 | tomatlan
# Processing Record 38 of Set 9 | santa flavia
# Processing Record 39 of Set 9 | andra
# Processing Record 40 of Set 9 | xiaoyi
# Processing Record 41 of Set 9 | floro
# Processing Record 42 of Set 9 | bereda
# Processing Record 43 of Set 9 | boa vista
# Processing Record 44 of Set 9 | san luis
# Processing Record 45 of Set 9 | college
# Processing Record 46 of Set 9 | buta
# Processing Record 47 of Set 9 | acapulco
# Processing Record 48 of Set 9 | coos bay
# Processing Record 49 of Set 9 | placido de castro
# Processing Record 50 of Set 9 | udachnyy
# Processing Record 1 of Set 10 | pangai
# Processing Record 2 of Set 10 | stawell
# Processing Record 3 of Set 10 | qasigiannguit
# Processing Record 4 of Set 10 | stornoway
# Processing Record 5 of Set 10 | jaroslaw
# Processing Record 6 of Set 10 | rocha
# Processing Record 7 of Set 10 | brecksville
# Processing Record 8 of Set 10 | mujiayingzi
# Processing Record 9 of Set 10 | harnosand
# Processing Record 10 of Set 10 | milkovo
# Processing Record 11 of Set 10 | kincardine
# Processing Record 12 of Set 10 | kupang
# Processing Record 13 of Set 10 | pulaski
# Processing Record 14 of Set 10 | vila franca do campo
# Processing Record 15 of Set 10 | sydney
# Processing Record 16 of Set 10 | sioux falls
# Processing Record 17 of Set 10 | luanda
# Processing Record 18 of Set 10 | araouane
# Processing Record 19 of Set 10 | sovetskiy
# Processing Record 20 of Set 10 | coquimbo
# Processing Record 21 of Set 10 | manggar
# Processing Record 22 of Set 10 | bubaque
# Processing Record 23 of Set 10 | kachug
# Processing Record 24 of Set 10 | san jose
# Processing Record 25 of Set 10 | fare
# Processing Record 26 of Set 10 | yeppoon
# Processing Record 27 of Set 10 | harper
# Processing Record 28 of Set 10 | nantucket
# Processing Record 29 of Set 10 | isabela
# Processing Record 30 of Set 10 | porto santo
# Processing Record 31 of Set 10 | arroyo
# Processing Record 32 of Set 10 | shu
# Processing Record 33 of Set 10 | talas
# Processing Record 34 of Set 10 | cayenne
# Processing Record 35 of Set 10 | tifton
# Processing Record 36 of Set 10 | tamandare
# Processing Record 37 of Set 10 | shingu
# Processing Record 38 of Set 10 | nerchinskiy zavod
# Processing Record 39 of Set 10 | halifax
# Processing Record 40 of Set 10 | edzell
# Processing Record 41 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 10 | mozarlandia
# Processing Record 43 of Set 10 | naze
# Processing Record 44 of Set 10 | pathein
# Processing Record 45 of Set 10 | blairmore
# Processing Record 46 of Set 10 | rajgarh
# Processing Record 47 of Set 10 | balkanabat
# Processing Record 48 of Set 10 | borogontsy
# Processing Record 49 of Set 10 | vengerovo
# Processing Record 50 of Set 10 | tucurui
# Processing Record 1 of Set 11 | basco
# Processing Record 2 of Set 11 | ahumada
# City not found. Skipping...
# Processing Record 3 of Set 11 | sharjah
# Processing Record 4 of Set 11 | sulphur
# Processing Record 5 of Set 11 | atasu
# Processing Record 6 of Set 11 | romans-sur-isere
# Processing Record 7 of Set 11 | wattegama
# Processing Record 8 of Set 11 | namatanai
# Processing Record 9 of Set 11 | krasnovka
# Processing Record 10 of Set 11 | tarrega
# Processing Record 11 of Set 11 | hovd
# Processing Record 12 of Set 11 | walvis bay
# Processing Record 13 of Set 11 | whyalla
# Processing Record 14 of Set 11 | kidal
# Processing Record 15 of Set 11 | kavieng
# Processing Record 16 of Set 11 | moreira sales
# Processing Record 17 of Set 11 | guerrero negro
# Processing Record 18 of Set 11 | trairi
# Processing Record 19 of Set 11 | martin
# Processing Record 20 of Set 11 | noumea
# Processing Record 21 of Set 11 | yenagoa
# Processing Record 22 of Set 11 | kyrylivka
# Processing Record 23 of Set 11 | dwarka
# Processing Record 24 of Set 11 | severo-yeniseyskiy
# Processing Record 25 of Set 11 | san carlos de bariloche
# Processing Record 26 of Set 11 | maarianhamina
# Processing Record 27 of Set 11 | svetlyy
# Processing Record 28 of Set 11 | bonavista
# Processing Record 29 of Set 11 | khasan
# Processing Record 30 of Set 11 | raozan
# City not found. Skipping...
# Processing Record 31 of Set 11 | alenquer
# Processing Record 32 of Set 11 | deputatskiy
# Processing Record 33 of Set 11 | bima
# Processing Record 34 of Set 11 | namibe
# Processing Record 35 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 11 | aban
# Processing Record 37 of Set 11 | manglaur
# Processing Record 38 of Set 11 | itaporanga
# Processing Record 39 of Set 11 | kizner
# Processing Record 40 of Set 11 | balezino
# Processing Record 41 of Set 11 | sibolga
# Processing Record 42 of Set 11 | koslan
# Processing Record 43 of Set 11 | camacupa
# Processing Record 44 of Set 11 | muisne
# Processing Record 45 of Set 11 | bilma
# Processing Record 46 of Set 11 | feijo
# Processing Record 47 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 48 of Set 11 | peterhead
# Processing Record 49 of Set 11 | briancon
# Processing Record 50 of Set 11 | porto murtinho
# Processing Record 1 of Set 12 | mabaruma
# Processing Record 2 of Set 12 | maumere
# Processing Record 3 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 12 | meulaboh
# Processing Record 5 of Set 12 | taunggyi
# Processing Record 6 of Set 12 | pochutla
# Processing Record 7 of Set 12 | wangqing
# Processing Record 8 of Set 12 | taitung
# Processing Record 9 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 12 | chipata
# Processing Record 11 of Set 12 | alyangula
# Processing Record 12 of Set 12 | boende
# Processing Record 13 of Set 12 | margate
# Processing Record 14 of Set 12 | broken hill
# Processing Record 15 of Set 12 | qinzhou
# Processing Record 16 of Set 12 | yumen
# Processing Record 17 of Set 12 | nagram
# Processing Record 18 of Set 12 | borujan
# City not found. Skipping...
# Processing Record 19 of Set 12 | wampusirpi
# City not found. Skipping...
# Processing Record 20 of Set 12 | sabang
# Processing Record 21 of Set 12 | awjilah
# Processing Record 22 of Set 12 | homer
# Processing Record 23 of Set 12 | touros
# Processing Record 24 of Set 12 | roszke
# Processing Record 25 of Set 12 | karla
# Processing Record 26 of Set 12 | barberena
# Processing Record 27 of Set 12 | norton
# Processing Record 28 of Set 12 | karamken
# City not found. Skipping...
# Processing Record 29 of Set 12 | baculin
# Processing Record 30 of Set 12 | kurilsk
# Processing Record 31 of Set 12 | bosaso
# Processing Record 32 of Set 12 | hagere hiywet
# Processing Record 33 of Set 12 | thinadhoo
# Processing Record 34 of Set 12 | plettenberg bay
# Processing Record 35 of Set 12 | batemans bay
# Processing Record 36 of Set 12 | hami
# Processing Record 37 of Set 12 | nanhai
# Processing Record 38 of Set 12 | talnakh
# Processing Record 39 of Set 12 | gigmoto
# Processing Record 40 of Set 12 | the valley
# Processing Record 41 of Set 12 | hamilton
# Processing Record 42 of Set 12 | killini
# City not found. Skipping...
# Processing Record 43 of Set 12 | saint petersburg
# Processing Record 44 of Set 12 | tabou
# Processing Record 45 of Set 12 | lima
# Processing Record 46 of Set 12 | palmas bellas
# Processing Record 47 of Set 12 | buraydah
# Processing Record 48 of Set 12 | gagino
# Processing Record 49 of Set 12 | tupaciguara
# Processing Record 50 of Set 12 | hvammstangi
# City not found. Skipping...
# Processing Record 1 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 13 | mayo
# Processing Record 3 of Set 13 | baleshwar
# Processing Record 4 of Set 13 | hirado
# Processing Record 5 of Set 13 | inuvik
# Processing Record 6 of Set 13 | hambantota
# Processing Record 7 of Set 13 | hobyo
# Processing Record 8 of Set 13 | sioux lookout
# Processing Record 9 of Set 13 | krutinka
# Processing Record 10 of Set 13 | yar-sale
# Processing Record 11 of Set 13 | elverum
# Processing Record 12 of Set 13 | kutum
# Processing Record 13 of Set 13 | dolores
# Processing Record 14 of Set 13 | linhares
# Processing Record 15 of Set 13 | sabha
# Processing Record 16 of Set 13 | mopti
# Processing Record 17 of Set 13 | nakhon nayok
# Processing Record 18 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 13 | panagar
# Processing Record 20 of Set 13 | maues
# Processing Record 21 of Set 13 | pangkalanbuun
# Processing Record 22 of Set 13 | sao joao da barra
# Processing Record 23 of Set 13 | weiser
# Processing Record 24 of Set 13 | waddan
# Processing Record 25 of Set 13 | honiara
# Processing Record 26 of Set 13 | mahanoro
# Processing Record 27 of Set 13 | assiniboia
# Processing Record 28 of Set 13 | adeje
# Processing Record 29 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 13 | great falls
# Processing Record 31 of Set 13 | chirongui
# Processing Record 32 of Set 13 | shakawe
# Processing Record 33 of Set 13 | danville
# Processing Record 34 of Set 13 | griffith
# Processing Record 35 of Set 13 | la orilla
# Processing Record 36 of Set 13 | mendahara
# City not found. Skipping...
# Processing Record 37 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 13 | sarangani
# Processing Record 39 of Set 13 | tukrah
# Processing Record 40 of Set 13 | cardoso
# Processing Record 41 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 13 | havoysund
# Processing Record 43 of Set 13 | tabatinga
# Processing Record 44 of Set 13 | hamada
# Processing Record 45 of Set 13 | guaraniacu
# Processing Record 46 of Set 13 | roros
# Processing Record 47 of Set 13 | tocopilla
# Processing Record 48 of Set 13 | vila
# Processing Record 49 of Set 13 | oranjemund
# Processing Record 50 of Set 13 | sola
# Processing Record 1 of Set 14 | eugene
# Processing Record 2 of Set 14 | dvinskoy
# Processing Record 3 of Set 14 | westport
# Processing Record 4 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 14 | atlantic city
# Processing Record 6 of Set 14 | buala
# Processing Record 7 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 14 | naryan-mar
# Processing Record 9 of Set 14 | greenwood
# Processing Record 10 of Set 14 | changji
# Processing Record 11 of Set 14 | kohat
# Processing Record 12 of Set 14 | erzin
# Processing Record 13 of Set 14 | himora
# City not found. Skipping...
# Processing Record 14 of Set 14 | vardo
# Processing Record 15 of Set 14 | andrews
# Processing Record 16 of Set 14 | ayagoz
# Processing Record 17 of Set 14 | harer
# Processing Record 18 of Set 14 | san lawrenz
# Processing Record 19 of Set 14 | leh
# Processing Record 20 of Set 14 | miramar
# Processing Record 21 of Set 14 | brownwood
# Processing Record 22 of Set 14 | iranshahr
# Processing Record 23 of Set 14 | male
# Processing Record 24 of Set 14 | grinnell
# Processing Record 25 of Set 14 | bani
# Processing Record 26 of Set 14 | dalianwan
# Processing Record 27 of Set 14 | blagoyevo
# Processing Record 28 of Set 14 | ixtapa
# Processing Record 29 of Set 14 | asosa
# Processing Record 30 of Set 14 | joura
# Processing Record 31 of Set 14 | ahar
# Processing Record 32 of Set 14 | ingraj bazar
# Processing Record 33 of Set 14 | nalut
# Processing Record 34 of Set 14 | alexandria
# Processing Record 35 of Set 14 | kloulklubed
# Processing Record 36 of Set 14 | bom jesus
# Processing Record 37 of Set 14 | mahina
# Processing Record 38 of Set 14 | opuwo
# Processing Record 39 of Set 14 | sao jose da coroa grande
# Processing Record 40 of Set 14 | esna
# Processing Record 41 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 42 of Set 14 | benguela
# Processing Record 43 of Set 14 | la union
# Processing Record 44 of Set 14 | tres palos
# Processing Record 45 of Set 14 | usinsk
# Processing Record 46 of Set 14 | bud
# Processing Record 47 of Set 14 | kerema
# Processing Record 48 of Set 14 | bauchi
# Processing Record 49 of Set 14 | shakhtinsk
# Processing Record 50 of Set 14 | roald
# Processing Record 1 of Set 15 | yeniseysk
# Processing Record 2 of Set 15 | fuyang
# Processing Record 3 of Set 15 | caruray
# Processing Record 4 of Set 15 | kyzyl-suu
# Processing Record 5 of Set 15 | piranhas
# Processing Record 6 of Set 15 | balkhash
# Processing Record 7 of Set 15 | mandurah
# Processing Record 8 of Set 15 | sisimiut
# Processing Record 9 of Set 15 | zarinsk
# Processing Record 10 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 15 | puerto leguizamo
# Processing Record 12 of Set 15 | abnub
# Processing Record 13 of Set 15 | quesnel
# Processing Record 14 of Set 15 | ishigaki
# Processing Record 15 of Set 15 | taicheng
# Processing Record 16 of Set 15 | aitape
# Processing Record 17 of Set 15 | auala
# City not found. Skipping...
# Processing Record 18 of Set 15 | kisoro
# Processing Record 19 of Set 15 | mackay
# Processing Record 20 of Set 15 | ternate
# Processing Record 21 of Set 15 | tutoia
# Processing Record 22 of Set 15 | lorengau
# Processing Record 23 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 15 | kibala
# Processing Record 25 of Set 15 | emba
# Processing Record 26 of Set 15 | kamenka
# Processing Record 27 of Set 15 | los algarrobos
# Processing Record 28 of Set 15 | tebingtinggi
# Processing Record 29 of Set 15 | ca mau
# Processing Record 30 of Set 15 | hjelset
# Processing Record 31 of Set 15 | kasongo-lunda
# Processing Record 32 of Set 15 | templin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 674

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Qaanaaq  77.4840  -69.3632    -26.12        83           9
# 1  Ponta Do Sol  32.6667  -17.1000     75.00        68          17
# 2        Barrow  71.2906 -156.7887     17.62        79         100
# 3    Blackwater -23.5833  148.8833     61.30        81           0
# 4         Jizan  17.3333   42.6667     82.92        63           0
# 5          Adre  13.4667   22.2000     88.90        19          95
# 6   East London -33.0153   27.9116     72.54        83          20
# 7        Albany  42.6001  -73.9662     35.92        51           5
# 8         Akyab  20.1500   92.9000     79.50        76           0
# 9          Kaeo -35.1000  173.7833     57.33        91          89
#
#    Wind Speed      Description Country
# 0        6.26        clear sky      GL
# 1        6.62       few clouds      PT
# 2        8.05  overcast clouds      US
# 3        7.40        clear sky      AU
# 4        8.63        clear sky      SA
# 5        5.48  overcast clouds      TD
# 6       12.66       few clouds      ZA
# 7        5.99        clear sky      US
# 8       11.92        clear sky      MM
# 9        5.06  overcast clouds      NZ

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Description', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Qaanaaq      GL  77.4840  -69.3632    -26.12        83           9
# 1  Ponta Do Sol      PT  32.6667  -17.1000     75.00        68          17
# 2        Barrow      US  71.2906 -156.7887     17.62        79         100
# 3    Blackwater      AU -23.5833  148.8833     61.30        81           0
# 4         Jizan      SA  17.3333   42.6667     82.92        63           0
# 5          Adre      TD  13.4667   22.2000     88.90        19          95
# 6   East London      ZA -33.0153   27.9116     72.54        83          20
# 7        Albany      US  42.6001  -73.9662     35.92        51           5
# 8         Akyab      MM  20.1500   92.9000     79.50        76           0
# 9          Kaeo      NZ -35.1000  173.7833     57.33        91          89
#
#    Wind Speed      Description
# 0        6.26        clear sky
# 1        6.62       few clouds
# 2        8.05  overcast clouds
# 3        7.40        clear sky
# 4        8.63        clear sky
# 5        5.48  overcast clouds
# 6       12.66       few clouds
# 7        5.99        clear sky
# 8       11.92        clear sky
# 9        5.06  overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
