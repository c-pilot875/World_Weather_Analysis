# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    

    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, and weather description
        city_weather = requests.get(city_url).json()    
            
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | bambous virieux
# Processing Record 5 of Set 1 | roald
# Processing Record 6 of Set 1 | morecambe
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | hambantota
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | kavaratti
# Processing Record 15 of Set 1 | sommerda
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | vera cruz
# Processing Record 19 of Set 1 | hassleholm
# Processing Record 20 of Set 1 | kampot
# Processing Record 21 of Set 1 | baturaja
# Processing Record 22 of Set 1 | vao
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | kaitangata
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | zhigansk
# Processing Record 27 of Set 1 | semnan
# Processing Record 28 of Set 1 | kotma
# Processing Record 29 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 1 | hofn
# Processing Record 31 of Set 1 | port lincoln
# Processing Record 32 of Set 1 | balkanabat
# Processing Record 33 of Set 1 | axim
# Processing Record 34 of Set 1 | egvekinot
# Processing Record 35 of Set 1 | grindavik
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | chanika
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | hasaki
# Processing Record 41 of Set 1 | samarai
# Processing Record 42 of Set 1 | doftana
# Processing Record 43 of Set 1 | saldanha
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | souillac
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | port blair
# Processing Record 1 of Set 2 | asau
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | srednekolymsk
# Processing Record 4 of Set 2 | tingi
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | iberia
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | aberdeen
# Processing Record 10 of Set 2 | pevek
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 2 | antofagasta
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | nyurba
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | ovsyanka
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | concepcion
# Processing Record 24 of Set 2 | provideniya
# Processing Record 25 of Set 2 | hesperia
# Processing Record 26 of Set 2 | soledade
# Processing Record 27 of Set 2 | bajo baudo
# City not found. Skipping...
# Processing Record 28 of Set 2 | portobelo
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | raudeberg
# Processing Record 32 of Set 2 | puerto colombia
# Processing Record 33 of Set 2 | leningradskiy
# Processing Record 34 of Set 2 | andover
# Processing Record 35 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 2 | chuy
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | naze
# Processing Record 39 of Set 2 | enshi
# Processing Record 40 of Set 2 | faanui
# Processing Record 41 of Set 2 | santa rosalia
# Processing Record 42 of Set 2 | sur
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | vostok
# Processing Record 45 of Set 2 | husavik
# Processing Record 46 of Set 2 | half moon bay
# Processing Record 47 of Set 2 | cedar city
# Processing Record 48 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 2 | hualmay
# Processing Record 50 of Set 2 | nikolskoye
# Processing Record 1 of Set 3 | villa rica
# Processing Record 2 of Set 3 | lac du bonnet
# Processing Record 3 of Set 3 | ketchikan
# Processing Record 4 of Set 3 | denpasar
# Processing Record 5 of Set 3 | bridlington
# Processing Record 6 of Set 3 | te anau
# Processing Record 7 of Set 3 | broome
# Processing Record 8 of Set 3 | shirokiy
# Processing Record 9 of Set 3 | lorengau
# Processing Record 10 of Set 3 | ancud
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | bemidji
# Processing Record 13 of Set 3 | jishou
# Processing Record 14 of Set 3 | port elizabeth
# Processing Record 15 of Set 3 | kapit
# Processing Record 16 of Set 3 | tasiilaq
# Processing Record 17 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 3 | opuwo
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | arraial do cabo
# Processing Record 22 of Set 3 | victoria
# Processing Record 23 of Set 3 | zhanaozen
# Processing Record 24 of Set 3 | mamallapuram
# Processing Record 25 of Set 3 | quelimane
# Processing Record 26 of Set 3 | pisco
# Processing Record 27 of Set 3 | bengkulu
# Processing Record 28 of Set 3 | nishihara
# Processing Record 29 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 3 | hami
# Processing Record 31 of Set 3 | san carlos de bariloche
# Processing Record 32 of Set 3 | yerbogachen
# Processing Record 33 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 3 | kinshasa
# Processing Record 35 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | abiy adi
# City not found. Skipping...
# Processing Record 38 of Set 3 | makakilo city
# Processing Record 39 of Set 3 | klaksvik
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | nathdwara
# Processing Record 42 of Set 3 | morogoro
# Processing Record 43 of Set 3 | pangkalanbuun
# Processing Record 44 of Set 3 | anar darreh
# City not found. Skipping...
# Processing Record 45 of Set 3 | sao filipe
# Processing Record 46 of Set 3 | bambanglipuro
# Processing Record 47 of Set 3 | san patricio
# Processing Record 48 of Set 3 | ostrovnoy
# Processing Record 49 of Set 3 | cherskiy
# Processing Record 50 of Set 3 | longyearbyen
# Processing Record 1 of Set 4 | dingle
# Processing Record 2 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 4 | nabagram
# Processing Record 4 of Set 4 | cabedelo
# Processing Record 5 of Set 4 | kathmandu
# Processing Record 6 of Set 4 | veracruz
# Processing Record 7 of Set 4 | ribeirao bonito
# Processing Record 8 of Set 4 | hun
# Processing Record 9 of Set 4 | chokurdakh
# Processing Record 10 of Set 4 | shakawe
# Processing Record 11 of Set 4 | guantanamo
# Processing Record 12 of Set 4 | astoria
# Processing Record 13 of Set 4 | richards bay
# Processing Record 14 of Set 4 | xining
# Processing Record 15 of Set 4 | vanimo
# Processing Record 16 of Set 4 | loukhi
# Processing Record 17 of Set 4 | tautira
# Processing Record 18 of Set 4 | fernie
# Processing Record 19 of Set 4 | hays
# Processing Record 20 of Set 4 | nelson bay
# Processing Record 21 of Set 4 | camacha
# Processing Record 22 of Set 4 | lakes entrance
# Processing Record 23 of Set 4 | kualakapuas
# Processing Record 24 of Set 4 | mayo
# Processing Record 25 of Set 4 | katangli
# Processing Record 26 of Set 4 | sioux lookout
# Processing Record 27 of Set 4 | san cristobal
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | bathsheba
# Processing Record 30 of Set 4 | zeya
# Processing Record 31 of Set 4 | benjamin hill
# Processing Record 32 of Set 4 | dubenskiy
# City not found. Skipping...
# Processing Record 33 of Set 4 | aswan
# Processing Record 34 of Set 4 | praia
# Processing Record 35 of Set 4 | toging
# City not found. Skipping...
# Processing Record 36 of Set 4 | police nad metuji
# Processing Record 37 of Set 4 | torbay
# Processing Record 38 of Set 4 | coquimbo
# Processing Record 39 of Set 4 | airai
# Processing Record 40 of Set 4 | inhambane
# Processing Record 41 of Set 4 | avera
# Processing Record 42 of Set 4 | miraflores
# Processing Record 43 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 4 | rongcheng
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | lao cai
# Processing Record 48 of Set 4 | roros
# Processing Record 49 of Set 4 | hithadhoo
# Processing Record 50 of Set 4 | nantucket
# Processing Record 1 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 5 | lagoa
# Processing Record 3 of Set 5 | sao miguel do araguaia
# Processing Record 4 of Set 5 | cozumel
# Processing Record 5 of Set 5 | bilma
# Processing Record 6 of Set 5 | olafsvik
# Processing Record 7 of Set 5 | kiyevskoye
# Processing Record 8 of Set 5 | smithers
# Processing Record 9 of Set 5 | nouadhibou
# Processing Record 10 of Set 5 | kimparana
# Processing Record 11 of Set 5 | college
# Processing Record 12 of Set 5 | kidal
# Processing Record 13 of Set 5 | ugoofaaru
# Processing Record 14 of Set 5 | sa kaeo
# Processing Record 15 of Set 5 | ixtapa
# Processing Record 16 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 17 of Set 5 | maldonado
# Processing Record 18 of Set 5 | kanpur
# Processing Record 19 of Set 5 | tiksi
# Processing Record 20 of Set 5 | amapa
# Processing Record 21 of Set 5 | tadine
# Processing Record 22 of Set 5 | paraiso
# Processing Record 23 of Set 5 | thompson
# Processing Record 24 of Set 5 | ruy barbosa
# Processing Record 25 of Set 5 | benjamin constant
# Processing Record 26 of Set 5 | san policarpo
# Processing Record 27 of Set 5 | vila velha
# Processing Record 28 of Set 5 | lisala
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | saint-philippe
# Processing Record 31 of Set 5 | zhob
# Processing Record 32 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 5 | north platte
# Processing Record 34 of Set 5 | san ramon de la nueva oran
# Processing Record 35 of Set 5 | aksarka
# Processing Record 36 of Set 5 | iqaluit
# Processing Record 37 of Set 5 | san roque
# Processing Record 38 of Set 5 | huangmei
# Processing Record 39 of Set 5 | ribeira grande
# Processing Record 40 of Set 5 | sawakin
# Processing Record 41 of Set 5 | scalea
# Processing Record 42 of Set 5 | muros
# Processing Record 43 of Set 5 | carutapera
# Processing Record 44 of Set 5 | portland
# Processing Record 45 of Set 5 | marfino
# Processing Record 46 of Set 5 | kahului
# Processing Record 47 of Set 5 | los negros
# Processing Record 48 of Set 5 | barstow
# Processing Record 49 of Set 5 | umm kaddadah
# Processing Record 50 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 6 | saint-augustin
# Processing Record 2 of Set 6 | yar-sale
# Processing Record 3 of Set 6 | evensk
# Processing Record 4 of Set 6 | pafos
# Processing Record 5 of Set 6 | anadyr
# Processing Record 6 of Set 6 | bubaque
# Processing Record 7 of Set 6 | manzhouli
# Processing Record 8 of Set 6 | lebu
# Processing Record 9 of Set 6 | tay ninh
# Processing Record 10 of Set 6 | dabat
# Processing Record 11 of Set 6 | nuuk
# Processing Record 12 of Set 6 | shubarkuduk
# Processing Record 13 of Set 6 | mecca
# Processing Record 14 of Set 6 | la rioja
# Processing Record 15 of Set 6 | labrea
# Processing Record 16 of Set 6 | qiongshan
# Processing Record 17 of Set 6 | vestmannaeyjar
# Processing Record 18 of Set 6 | sibi
# Processing Record 19 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 20 of Set 6 | emerald
# Processing Record 21 of Set 6 | north bend
# Processing Record 22 of Set 6 | san quintin
# Processing Record 23 of Set 6 | diu
# Processing Record 24 of Set 6 | dingli
# Processing Record 25 of Set 6 | jacqueville
# Processing Record 26 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 27 of Set 6 | doha
# Processing Record 28 of Set 6 | constitucion
# Processing Record 29 of Set 6 | heyang
# Processing Record 30 of Set 6 | kupang
# Processing Record 31 of Set 6 | sampit
# Processing Record 32 of Set 6 | forquilhinha
# Processing Record 33 of Set 6 | trairi
# Processing Record 34 of Set 6 | sayyan
# Processing Record 35 of Set 6 | moyale
# Processing Record 36 of Set 6 | chuguyevka
# Processing Record 37 of Set 6 | liverpool
# Processing Record 38 of Set 6 | porto walter
# Processing Record 39 of Set 6 | kalemie
# Processing Record 40 of Set 6 | svetlogorsk
# Processing Record 41 of Set 6 | kodinsk
# Processing Record 42 of Set 6 | chickasha
# Processing Record 43 of Set 6 | maniitsoq
# Processing Record 44 of Set 6 | alofi
# Processing Record 45 of Set 6 | hastings
# Processing Record 46 of Set 6 | salinopolis
# Processing Record 47 of Set 6 | nanortalik
# Processing Record 48 of Set 6 | hamilton
# Processing Record 49 of Set 6 | samoylovka
# Processing Record 50 of Set 6 | skjervoy
# Processing Record 1 of Set 7 | peniche
# Processing Record 2 of Set 7 | ulaangom
# Processing Record 3 of Set 7 | biscarrosse
# Processing Record 4 of Set 7 | ilulissat
# Processing Record 5 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 7 | buy
# Processing Record 7 of Set 7 | ahuimanu
# Processing Record 8 of Set 7 | lakhdenpokhya
# Processing Record 9 of Set 7 | gizo
# Processing Record 10 of Set 7 | burkhala
# City not found. Skipping...
# Processing Record 11 of Set 7 | beloha
# Processing Record 12 of Set 7 | fortuna
# Processing Record 13 of Set 7 | synya
# Processing Record 14 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 7 | vila franca do campo
# Processing Record 16 of Set 7 | severo-yeniseyskiy
# Processing Record 17 of Set 7 | poum
# Processing Record 18 of Set 7 | lac-au-saumon
# Processing Record 19 of Set 7 | yumen
# Processing Record 20 of Set 7 | alyangula
# Processing Record 21 of Set 7 | yola
# Processing Record 22 of Set 7 | pimentel
# Processing Record 23 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 7 | along
# Processing Record 25 of Set 7 | pemangkat
# Processing Record 26 of Set 7 | lodja
# Processing Record 27 of Set 7 | ishigaki
# Processing Record 28 of Set 7 | baraboo
# Processing Record 29 of Set 7 | tianpeng
# Processing Record 30 of Set 7 | mount gambier
# Processing Record 31 of Set 7 | soe
# Processing Record 32 of Set 7 | bintulu
# Processing Record 33 of Set 7 | asfi
# Processing Record 34 of Set 7 | saint george
# Processing Record 35 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 7 | saint-francois
# Processing Record 37 of Set 7 | burgeo
# Processing Record 38 of Set 7 | matadi
# Processing Record 39 of Set 7 | bani walid
# Processing Record 40 of Set 7 | ponta delgada
# Processing Record 41 of Set 7 | lakki marwat
# Processing Record 42 of Set 7 | whitianga
# Processing Record 43 of Set 7 | iskateley
# Processing Record 44 of Set 7 | nome
# Processing Record 45 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 7 | haines junction
# Processing Record 47 of Set 7 | pathein
# Processing Record 48 of Set 7 | fairbanks
# Processing Record 49 of Set 7 | puga
# Processing Record 50 of Set 7 | mount isa
# Processing Record 1 of Set 8 | mitchell
# Processing Record 2 of Set 8 | kimbe
# Processing Record 3 of Set 8 | ozernovskiy
# Processing Record 4 of Set 8 | bayshore gardens
# Processing Record 5 of Set 8 | yangambi
# Processing Record 6 of Set 8 | araouane
# Processing Record 7 of Set 8 | la romana
# Processing Record 8 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 8 | acapulco
# Processing Record 10 of Set 8 | karratha
# Processing Record 11 of Set 8 | burica
# City not found. Skipping...
# Processing Record 12 of Set 8 | luderitz
# Processing Record 13 of Set 8 | deputatskiy
# Processing Record 14 of Set 8 | los llanos de aridane
# Processing Record 15 of Set 8 | ushtobe
# Processing Record 16 of Set 8 | kismayo
# Processing Record 17 of Set 8 | sorong
# Processing Record 18 of Set 8 | cayenne
# Processing Record 19 of Set 8 | penzance
# Processing Record 20 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 8 | kutum
# Processing Record 22 of Set 8 | saint-pierre
# Processing Record 23 of Set 8 | abu samrah
# Processing Record 24 of Set 8 | palkino
# Processing Record 25 of Set 8 | witu
# Processing Record 26 of Set 8 | diego de almagro
# Processing Record 27 of Set 8 | galle
# Processing Record 28 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 8 | urumqi
# Processing Record 30 of Set 8 | caravelas
# Processing Record 31 of Set 8 | verkhnevilyuysk
# Processing Record 32 of Set 8 | semey
# Processing Record 33 of Set 8 | menongue
# Processing Record 34 of Set 8 | sobolevo
# Processing Record 35 of Set 8 | brae
# Processing Record 36 of Set 8 | dunmore east
# Processing Record 37 of Set 8 | outjo
# Processing Record 38 of Set 8 | dubbo
# Processing Record 39 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 8 | kitakata
# Processing Record 41 of Set 8 | mareeba
# Processing Record 42 of Set 8 | tuxtla
# Processing Record 43 of Set 8 | forestville
# Processing Record 44 of Set 8 | narsaq
# Processing Record 45 of Set 8 | sergeyevka
# Processing Record 46 of Set 8 | najran
# Processing Record 47 of Set 8 | gumusyaka
# City not found. Skipping...
# Processing Record 48 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 49 of Set 8 | zeerust
# Processing Record 50 of Set 8 | itarema
# Processing Record 1 of Set 9 | merauke
# Processing Record 2 of Set 9 | lavrentiya
# Processing Record 3 of Set 9 | puri
# Processing Record 4 of Set 9 | matagami
# Processing Record 5 of Set 9 | kanigoro
# Processing Record 6 of Set 9 | bonthe
# Processing Record 7 of Set 9 | dalsingh sarai
# Processing Record 8 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 9 | helong
# Processing Record 10 of Set 9 | missao velha
# Processing Record 11 of Set 9 | sisimiut
# Processing Record 12 of Set 9 | punto fijo
# Processing Record 13 of Set 9 | keokuk
# Processing Record 14 of Set 9 | berdigestyakh
# Processing Record 15 of Set 9 | ternate
# Processing Record 16 of Set 9 | westport
# Processing Record 17 of Set 9 | plettenberg bay
# Processing Record 18 of Set 9 | vila do maio
# Processing Record 19 of Set 9 | komsomolskiy
# Processing Record 20 of Set 9 | lovozero
# Processing Record 21 of Set 9 | minsk
# Processing Record 22 of Set 9 | nanakuli
# Processing Record 23 of Set 9 | geraldton
# Processing Record 24 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 25 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 26 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 9 | shingu
# Processing Record 30 of Set 9 | berlevag
# Processing Record 31 of Set 9 | dukat
# Processing Record 32 of Set 9 | ilo
# Processing Record 33 of Set 9 | mutis
# Processing Record 34 of Set 9 | poltavka
# Processing Record 35 of Set 9 | guarda
# Processing Record 36 of Set 9 | manicore
# Processing Record 37 of Set 9 | damienesti
# Processing Record 38 of Set 9 | trois-rivieres
# Processing Record 39 of Set 9 | vostochnyy
# Processing Record 40 of Set 9 | tungor
# Processing Record 41 of Set 9 | batagay
# Processing Record 42 of Set 9 | port hardy
# Processing Record 43 of Set 9 | prince rupert
# Processing Record 44 of Set 9 | namibe
# Processing Record 45 of Set 9 | nemuro
# Processing Record 46 of Set 9 | clarence town
# Processing Record 47 of Set 9 | shaowu
# Processing Record 48 of Set 9 | dondo
# Processing Record 49 of Set 9 | pangnirtung
# Processing Record 50 of Set 9 | clyde river
# Processing Record 1 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 10 | novyy svit
# Processing Record 3 of Set 10 | kysyl-syr
# Processing Record 4 of Set 10 | grand gaube
# Processing Record 5 of Set 10 | lloydminster
# Processing Record 6 of Set 10 | ustrzyki dolne
# Processing Record 7 of Set 10 | hirara
# Processing Record 8 of Set 10 | shelburne
# Processing Record 9 of Set 10 | okhotsk
# Processing Record 10 of Set 10 | ayagoz
# Processing Record 11 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 12 of Set 10 | houma
# Processing Record 13 of Set 10 | ximei
# Processing Record 14 of Set 10 | mersing
# Processing Record 15 of Set 10 | sirnak
# Processing Record 16 of Set 10 | tebingtinggi
# Processing Record 17 of Set 10 | arona
# Processing Record 18 of Set 10 | ardakan
# Processing Record 19 of Set 10 | groa
# Processing Record 20 of Set 10 | inongo
# Processing Record 21 of Set 10 | moron
# Processing Record 22 of Set 10 | afua
# Processing Record 23 of Set 10 | kieta
# Processing Record 24 of Set 10 | pontian kecil
# Processing Record 25 of Set 10 | molepolole
# Processing Record 26 of Set 10 | aklavik
# Processing Record 27 of Set 10 | escuintla
# Processing Record 28 of Set 10 | kavieng
# Processing Record 29 of Set 10 | high level
# Processing Record 30 of Set 10 | saint-georges
# Processing Record 31 of Set 10 | jalu
# Processing Record 32 of Set 10 | cidreira
# Processing Record 33 of Set 10 | general pico
# Processing Record 34 of Set 10 | lakatoro
# Processing Record 35 of Set 10 | batsfjord
# Processing Record 36 of Set 10 | kalya
# Processing Record 37 of Set 10 | zyryanka
# Processing Record 38 of Set 10 | luang prabang
# Processing Record 39 of Set 10 | labuhan
# Processing Record 40 of Set 10 | sibolga
# Processing Record 41 of Set 10 | vanavara
# Processing Record 42 of Set 10 | winton
# Processing Record 43 of Set 10 | dunedin
# Processing Record 44 of Set 10 | carevo
# City not found. Skipping...
# Processing Record 45 of Set 10 | panjab
# Processing Record 46 of Set 10 | dali
# Processing Record 47 of Set 10 | korla
# Processing Record 48 of Set 10 | durban
# Processing Record 49 of Set 10 | mabaruma
# Processing Record 50 of Set 10 | xinyu
# Processing Record 1 of Set 11 | tabasalu
# Processing Record 2 of Set 11 | karaton
# Processing Record 3 of Set 11 | parry sound
# Processing Record 4 of Set 11 | sitka
# Processing Record 5 of Set 11 | sault sainte marie
# Processing Record 6 of Set 11 | saint-jerome
# Processing Record 7 of Set 11 | halifax
# Processing Record 8 of Set 11 | turangi
# Processing Record 9 of Set 11 | gornoye loo
# Processing Record 10 of Set 11 | altay
# Processing Record 11 of Set 11 | chabahar
# Processing Record 12 of Set 11 | aksu
# Processing Record 13 of Set 11 | kayes
# Processing Record 14 of Set 11 | sosnovo-ozerskoye
# Processing Record 15 of Set 11 | lompoc
# Processing Record 16 of Set 11 | ouegoa
# Processing Record 17 of Set 11 | santa cruz cabralia
# Processing Record 18 of Set 11 | santa fe
# Processing Record 19 of Set 11 | qasigiannguit
# Processing Record 20 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 11 | pampa
# Processing Record 22 of Set 11 | aquiraz
# Processing Record 23 of Set 11 | durusu
# Processing Record 24 of Set 11 | amga
# Processing Record 25 of Set 11 | gouyave
# Processing Record 26 of Set 11 | codrington
# Processing Record 27 of Set 11 | zemio
# Processing Record 28 of Set 11 | hovd
# Processing Record 29 of Set 11 | waddan
# Processing Record 30 of Set 11 | tulun
# Processing Record 31 of Set 11 | puerto madryn
# Processing Record 32 of Set 11 | kaiyuan
# Processing Record 33 of Set 11 | sao joao da barra
# Processing Record 34 of Set 11 | porto novo
# Processing Record 35 of Set 11 | isangel
# Processing Record 36 of Set 11 | portales
# Processing Record 37 of Set 11 | khash
# Processing Record 38 of Set 11 | tromso
# Processing Record 39 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 11 | angoche
# Processing Record 41 of Set 11 | rawson
# Processing Record 42 of Set 11 | quang ngai
# Processing Record 43 of Set 11 | bardiyah
# Processing Record 44 of Set 11 | eyl
# Processing Record 45 of Set 11 | praia da vitoria
# Processing Record 46 of Set 11 | simao
# Processing Record 47 of Set 11 | lasa
# Processing Record 48 of Set 11 | ola
# Processing Record 49 of Set 11 | sambava
# Processing Record 50 of Set 11 | wajima
# Processing Record 1 of Set 12 | huescar
# Processing Record 2 of Set 12 | talara
# Processing Record 3 of Set 12 | sumter
# Processing Record 4 of Set 12 | veraval
# Processing Record 5 of Set 12 | upata
# Processing Record 6 of Set 12 | talnakh
# Processing Record 7 of Set 12 | abohar
# Processing Record 8 of Set 12 | promissao
# Processing Record 9 of Set 12 | moree
# Processing Record 10 of Set 12 | touros
# Processing Record 11 of Set 12 | shimoda
# Processing Record 12 of Set 12 | kruisfontein
# Processing Record 13 of Set 12 | mayor pablo lagerenza
# Processing Record 14 of Set 12 | den helder
# Processing Record 15 of Set 12 | norwich
# Processing Record 16 of Set 12 | riohacha
# Processing Record 17 of Set 12 | boyolangu
# Processing Record 18 of Set 12 | vardo
# Processing Record 19 of Set 12 | iralaya
# Processing Record 20 of Set 12 | potchefstroom
# Processing Record 21 of Set 12 | ust-kuyga
# Processing Record 22 of Set 12 | kenai
# Processing Record 23 of Set 12 | kosonsoy
# Processing Record 24 of Set 12 | bykovo
# Processing Record 25 of Set 12 | roma
# Processing Record 26 of Set 12 | cap malheureux
# Processing Record 27 of Set 12 | oktyabrskiy
# Processing Record 28 of Set 12 | nargana
# Processing Record 29 of Set 12 | oranjestad
# Processing Record 30 of Set 12 | tres arroyos
# Processing Record 31 of Set 12 | catuday
# Processing Record 32 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 33 of Set 12 | beringovskiy
# Processing Record 34 of Set 12 | bonavista
# Processing Record 35 of Set 12 | gat
# Processing Record 36 of Set 12 | viedma
# Processing Record 37 of Set 12 | freeport
# Processing Record 38 of Set 12 | farah
# Processing Record 39 of Set 12 | hit
# Processing Record 40 of Set 12 | fort nelson
# Processing Record 41 of Set 12 | ballina
# Processing Record 42 of Set 12 | sistranda
# Processing Record 43 of Set 12 | cayon
# Processing Record 44 of Set 12 | tabou
# Processing Record 45 of Set 12 | novaya igirma
# Processing Record 46 of Set 12 | camargo
# Processing Record 47 of Set 12 | aliartos
# Processing Record 48 of Set 12 | natal
# Processing Record 49 of Set 12 | itaituba
# Processing Record 50 of Set 12 | agirish
# Processing Record 1 of Set 13 | saskatoon
# Processing Record 2 of Set 13 | nanning
# Processing Record 3 of Set 13 | santa marta
# Processing Record 4 of Set 13 | duz
# City not found. Skipping...
# Processing Record 5 of Set 13 | mitu
# Processing Record 6 of Set 13 | sharjah
# Processing Record 7 of Set 13 | santa maria
# Processing Record 8 of Set 13 | pingzhuang
# Processing Record 9 of Set 13 | fairview
# Processing Record 10 of Set 13 | konstantinovskaya
# Processing Record 11 of Set 13 | rio gallegos
# Processing Record 12 of Set 13 | yatsuo
# Processing Record 13 of Set 13 | narimanov
# Processing Record 14 of Set 13 | sao geraldo do araguaia
# Processing Record 15 of Set 13 | sao jose da coroa grande
# Processing Record 16 of Set 13 | tecoanapa
# Processing Record 17 of Set 13 | cabo san lucas
# Processing Record 18 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 20 of Set 13 | usinsk
# Processing Record 21 of Set 13 | plover
# Processing Record 22 of Set 13 | vallenar
# Processing Record 23 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 13 | vreed en hoop
# City not found. Skipping...
# Processing Record 25 of Set 13 | sept-iles
# Processing Record 26 of Set 13 | newark
# Processing Record 27 of Set 13 | kendari
# Processing Record 28 of Set 13 | tchollire
# Processing Record 29 of Set 13 | port moresby
# Processing Record 30 of Set 13 | millington
# Processing Record 31 of Set 13 | luau
# Processing Record 32 of Set 13 | ginir
# Processing Record 33 of Set 13 | jurado
# Processing Record 34 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 13 | canala
# Processing Record 36 of Set 13 | cooma
# Processing Record 37 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 13 | orlik
# Processing Record 39 of Set 13 | martil
# Processing Record 40 of Set 13 | molchanovo
# Processing Record 41 of Set 13 | ambilobe
# Processing Record 42 of Set 13 | salalah
# Processing Record 43 of Set 13 | salta
# Processing Record 44 of Set 13 | sinnamary
# Processing Record 45 of Set 13 | miyako
# Processing Record 46 of Set 13 | houston
# Processing Record 47 of Set 13 | paamiut
# Processing Record 48 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 49 of Set 13 | novyy urengoy
# Processing Record 50 of Set 13 | saint-joseph
# Processing Record 1 of Set 14 | riyadh
# Processing Record 2 of Set 14 | hojai
# Processing Record 3 of Set 14 | akyab
# Processing Record 4 of Set 14 | beira
# Processing Record 5 of Set 14 | santa cruz
# Processing Record 6 of Set 14 | polyarnyy
# Processing Record 7 of Set 14 | dasuya
# Processing Record 8 of Set 14 | faya
# Processing Record 9 of Set 14 | balakliya
# Processing Record 10 of Set 14 | port macquarie
# Processing Record 11 of Set 14 | taltal
# Processing Record 12 of Set 14 | taoudenni
# Processing Record 13 of Set 14 | myski
# Processing Record 14 of Set 14 | belmonte
# Processing Record 15 of Set 14 | wysokie mazowieckie
# Processing Record 16 of Set 14 | ocos
# Processing Record 17 of Set 14 | nazarovo
# Processing Record 18 of Set 14 | alvaraes
# Processing Record 19 of Set 14 | kangaatsiaq
# Processing Record 20 of Set 14 | samfya
# Processing Record 21 of Set 14 | kawhia
# Processing Record 22 of Set 14 | imbituba
# Processing Record 23 of Set 14 | charters towers
# Processing Record 24 of Set 14 | byron bay
# Processing Record 25 of Set 14 | novikovo
# Processing Record 26 of Set 14 | qabis
# City not found. Skipping...
# Processing Record 27 of Set 14 | kaspiysk
# Processing Record 28 of Set 14 | kilindoni
# Processing Record 29 of Set 14 | katsuura
# Processing Record 30 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 31 of Set 14 | curaca
# Processing Record 32 of Set 14 | boden
# Processing Record 33 of Set 14 | dahra
# Processing Record 34 of Set 14 | khani
# Processing Record 35 of Set 14 | port hawkesbury
# Processing Record 36 of Set 14 | ende
# Processing Record 37 of Set 14 | sirfa
# City not found. Skipping...
# Processing Record 38 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 14 | biankouma
# Processing Record 40 of Set 14 | goderich
# Processing Record 41 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 14 | madang
# Processing Record 43 of Set 14 | nakskov
# Processing Record 44 of Set 14 | paramonga
# Processing Record 45 of Set 14 | yarke pole
# Processing Record 46 of Set 14 | urubamba
# Processing Record 47 of Set 14 | rocha
# Processing Record 48 of Set 14 | puerto escondido
# Processing Record 49 of Set 14 | kozan
# Processing Record 50 of Set 14 | kawalu
# Processing Record 1 of Set 15 | delta del tigre
# Processing Record 2 of Set 15 | acarau
# Processing Record 3 of Set 15 | maragogi
# Processing Record 4 of Set 15 | tottori
# Processing Record 5 of Set 15 | tabalosos
# Processing Record 6 of Set 15 | chara
# Processing Record 7 of Set 15 | tazmalt
# Processing Record 8 of Set 15 | okha
# Processing Record 9 of Set 15 | corrente
# Processing Record 10 of Set 15 | atar
# Processing Record 11 of Set 15 | yuci
# Processing Record 12 of Set 15 | buala
# Processing Record 13 of Set 15 | melfort
# Processing Record 14 of Set 15 | idah
# Processing Record 15 of Set 15 | alta floresta
# Processing Record 16 of Set 15 | kargasok
# Processing Record 17 of Set 15 | tilhar
# Processing Record 18 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 19 of Set 15 | birin
# Processing Record 20 of Set 15 | palana
# Processing Record 21 of Set 15 | cabra
# Processing Record 22 of Set 15 | mezen
# Processing Record 23 of Set 15 | girne
# Processing Record 24 of Set 15 | lazaro cardenas
# Processing Record 25 of Set 15 | teya
# Processing Record 26 of Set 15 | the pas
# Processing Record 27 of Set 15 | sorland
# Processing Record 28 of Set 15 | palmer
# Processing Record 29 of Set 15 | chicama
# Processing Record 30 of Set 15 | balestrand
# Processing Record 31 of Set 15 | sumbe
# Processing Record 32 of Set 15 | beisfjord
# Processing Record 33 of Set 15 | leshukonskoye
# Processing Record 34 of Set 15 | sedalia
# Processing Record 35 of Set 15 | primo tapia
# Processing Record 36 of Set 15 | tiznit
# Processing Record 37 of Set 15 | karibib
# Processing Record 38 of Set 15 | kohat
# Processing Record 39 of Set 15 | kautokeino
# Processing Record 40 of Set 15 | lephepe
# City not found. Skipping...
# Processing Record 41 of Set 15 | port-gentil
# Processing Record 42 of Set 15 | jinchang
# Processing Record 43 of Set 15 | thyboron
# Processing Record 44 of Set 15 | lekoni
# Processing Record 45 of Set 15 | ahipara
# Processing Record 46 of Set 15 | rincon
# Processing Record 47 of Set 15 | golden
# Processing Record 48 of Set 15 | taloqan
# Processing Record 49 of Set 15 | baruun-urt
# Processing Record 50 of Set 15 | aiquile
# Processing Record 1 of Set 16 | bastia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Butaritari   3.0707  172.7902     79.99        81          24
# 1     Norman Wells  65.2820 -126.8329      6.94        97         100
# 2        Busselton -33.6500  115.3333     57.29        83           0
# 3  Bambous Virieux -20.3428   57.7575     79.21        69          21
# 4            Roald  62.5833    6.1333     44.33        81           0
# 5        Morecambe  54.0684   -2.8611     46.40        95         100
# 6      Port Alfred -33.5906   26.8910     72.18        81          26
# 7           Bethel  41.3712  -73.4140     36.55        60          22
# 8          Ushuaia -54.8000  -68.3000     56.86        47          40
# 9           Albany  42.6001  -73.9662     33.37        52           4
#
#    Wind Speed       Description
# 0       11.79        light rain
# 1        3.04        light snow
# 2       11.23         clear sky
# 3        9.69        few clouds
# 4        9.22         clear sky
# 5        1.99   overcast clouds
# 6        5.01  scattered clouds
# 7        4.00        few clouds
# 8       16.11  scattered clouds
# 9        3.00         clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#        Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   3.0707  172.7902     79.99        81          24       11.79
# 1  65.2820 -126.8329      6.94        97         100        3.04
# 2 -33.6500  115.3333     57.29        83           0       11.23
# 3 -20.3428   57.7575     79.21        69          21        9.69
# 4  62.5833    6.1333     44.33        81           0        9.22
# 5  54.0684   -2.8611     46.40        95         100        1.99
# 6 -33.5906   26.8910     72.18        81          26        5.01
# 7  41.3712  -73.4140     36.55        60          22        4.00
# 8 -54.8000  -68.3000     56.86        47          40       16.11
# 9  42.6001  -73.9662     33.37        52           4        3.00
#
#         Description
# 0        light rain
# 1        light snow
# 2         clear sky
# 3        few clouds
# 4         clear sky
# 5   overcast clouds
# 6  scattered clouds
# 7        few clouds
# 8  scattered clouds
# 9         clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
